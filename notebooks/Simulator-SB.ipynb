# %%
# %reload_ext autoreload
# %autoreload 2
import sys
sys.path.append('./')
sys.path.append('../')
import sim.sim

# %%
import sim.sim
df = sim.sim.load_candidates()
df = df.query('_DEJ2000 > 0') # apply some global cuts
df = sim.sim.combine_samples(df)
tks = df[df.inany]
# Out:
# in bright
# nstars = 48, nplanets=50, nnights = 52.2,
#
# only in bright
# nstars = 45, nplanets=47, nnights = 49.9,
#
# in close
# nstars = 9, nplanets=10, nnights = 42.0,
#
# only in close
# nstars = 9, nplanets=10, nnights = 42.0,
#
# in multi
# nstars = 5, nplanets=10, nnights = 2.2,
#
# only in multi
# nstars = 5, nplanets=9, nnights = 2.2,
#
# in usp
# nstars = 5, nplanets=5, nnights = 3.9,
#
# only in usp
# nstars = 3, nplanets=3, nnights = 2.1,
#
# --------------------------------------------------------------------------------
# Total
# nstars = 64, nplanets=72, nnights = 97.9,
#
# Program overlap
# nprograms
# 0    2111
# 1      69
# 2       3
# dtype: int64

# %% [markdown]
# # Histogram plots

# %%
import sim.plots
sim.plots.histograms(tks)

# %% [markdown]
# # Scatter plots

# %%
import sim.plots
sim.plots.scatter_plots(tks)

# %% [markdown]
# # H-R Diagram plot

# %%
import sim.plots
sim.plots.hr_plot(tks)

# %% [markdown]
# # Save target list

# %%
tks.to_csv('target_list.csv', index=False)

# %% [markdown]
# # TODO list

# %%
"""
overheads
more agressive jitter cut
add jitter tests into time allocation
shallow survey
HR diagram figure
M dwarfs, can cut on planet properties
code on repo
ramp up from 10.5 to 60k (fainter than 12)
"""
# Out:
# '\noverheads\nmore agressive jitter cut\nadd jitter tests into time allocation\nshallow survey\nHR diagram figure\nM dwarfs, can cut on planet properties\ncode on repo\nramp up from 10.5 to 60k (fainter than 12)\n'

# %%
sys.path.append('../')
from sim import utils
